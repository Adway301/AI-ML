# %%
import matplotlib.pyplot as plt

# %%
oscar=["A","B","C","D","E"]
year=[2011,20013,2017,2019,2020]
revenue=[100,200,500,200,300]
no_movies=[1000,2000,3000,4000,5000]
plt.plot(revenue,year, label="year")
plt.plot(revenue,no_movies, label="no movies")
plt.title("Revenue vs year and revenue vs no movies")
plt.xlabel("revenue")
plt.ylabel("year/no movies")
plt.legend()
